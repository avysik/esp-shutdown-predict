# %%
import pandas as pd

path = "src/data/dfpp.parquet"

df = pd.read_parquet(path)

print("shape:", df.shape)
print("\ncolumns:")
print(df.columns.tolist())

print("\ndtypes:")
print(df.dtypes)

print("\nhead:")
display(df.head())
# Out:
# shape: (5531040, 19)
#
# columns:
# ['run_id', 'ValueDate', 'Активная мощность', 'Дисбаланс напряжений', 'Дисбаланс токов', 'Загрузка', 'Коэффиц.мощности', 'Напряжение AC(АВ)', 'Напряжение BA(СА)', 'Напряжение CB(ВС)', 'Р на приеме насоса', 'Сопротив.изоляции', 'Температура двигателя', 'Ток фазы А', 'Ток фазы B', 'Ток фазы C', 'window_numb', 'status_window_24', 'status_window_48']
#
# dtypes:
# run_id                            int64
# ValueDate                datetime64[ns]
# Активная мощность               float64
# Дисбаланс напряжений            float64
# Дисбаланс токов                 float64
# Загрузка                        float64
# Коэффиц.мощности                float64
# Напряжение AC(АВ)               float64
# Напряжение BA(СА)               float64
# Напряжение CB(ВС)               float64
# Р на приеме насоса              float64
# Сопротив.изоляции               float64
# Температура двигателя           float64
# Ток фазы А                      float64
# Ток фазы B                      float64
# Ток фазы C                      float64
# window_numb                     float64
# status_window_24                    str
# status_window_48                    str
# dtype: object
#
# head:
#    run_id           ValueDate  Активная мощность  Дисбаланс напряжений  \
# 0       1 2022-03-15 18:13:00               6.20                   1.0
# 1       1 2022-03-15 18:14:00               6.18                   1.0
# 2       1 2022-03-15 18:15:00               6.16                   1.0
# 3       1 2022-03-15 18:16:00               6.14                   1.0
# 4       1 2022-03-15 18:17:00               6.12                   1.0
#
#    Дисбаланс токов  Загрузка  Коэффиц.мощности  Напряжение AC(АВ)  \
# 0              2.0      44.0              0.72              397.0
# 1              2.0      44.0              0.72              396.8
# 2              2.0      44.0              0.72              396.6
# 3              2.0      44.0              0.72              396.4
# 4              2.0      44.0              0.72              396.2
#
#    Напряжение BA(СА)  Напряжение CB(ВС)  Р на приеме насоса  \
# 0              393.0              395.0                 2.7
# 1              392.8              394.8                 2.7
# 2              392.6              394.6                 2.7
# 3              392.4              394.4                 2.7
# 4              392.2              394.2                 2.7
#
#    Сопротив.изоляции  Температура двигателя  Ток фазы А  Ток фазы B  \
# 0             9999.0                   41.0   20.900000   21.300001
# 1             9999.0                   41.0   20.880000   21.280001
# 2             9999.0                   41.0   20.860000   21.260001
# 3             9999.0                   41.0   20.840001   21.240001
# 4             9999.0                   41.0   20.820001   21.220001
#
#    Ток фазы C  window_numb status_window_24 status_window_48
# 0   21.300001          0.0      normal_work      normal_work
# 1   21.280001          0.0      normal_work      normal_work
# 2   21.260001          0.0      normal_work      normal_work
# 3   21.240001          0.0      normal_work      normal_work
# 4   21.220001          0.0      normal_work      normal_work

# %%
# Проверка временной оси
print("min timestamp:", df["value_date"].min())
print("max timestamp:", df["value_date"].max())

print("\nunique step:")
print(df["value_date"].diff().dropna().unique())

# Есть ли пропуски
print("\nNaNs per column:")
print(df.isna().sum())

# Простая статистика
print("\ndescribe:")
display(df.describe())
# Out:
# min timestamp: 2020-01-01 00:00:00
# max timestamp: 2020-01-01 23:59:00
#
# unique step:
# <TimedeltaArray>
# ['0 days 00:01:00']
# Length: 1, dtype: timedelta64[us]
#
# NaNs per column:
# value_date             0
# esp_id                 0
# run_id                 0
# stage_num              0
# pump_freq_hz           0
# p_int_atma             0
# t_int_c                0
# gamma_g                0
# gamma_o                0
# gamma_w                0
# rsb_m3m3               0
# rp_m3m3                0
# pb_atma                0
# t_res_c                0
# bob_m3m3               0
# muob_cp                0
# fw_fr                  0
# q_gas_free_sm3day      0
# q_liq_sm3day           0
# mu_mix_cst             0
# gas_fraction_d         0
# q_mix_rc_m3day         0
# p_dis_atma             0
# t_dis_c                0
# head_m                 0
# eff_esp_d              0
# power_fluid_w          0
# power_esp_w            0
# system_eff_d           0
# u_surf_v               0
# motor_u_nom_lin_v      0
# motor_p_nom_kw         0
# motor_f_nom_hz         0
# motor_eff_nom_fr       0
# motor_cosphi_nom_fr    0
# motor_slip_nom_fr      0
# motor_id               0
# motor_u_lin_v          0
# motor_i_lin_a          0
# motor_cosphi           0
# motor_slip             0
# motor_eff_d            0
# motor_p_shaft_kw       0
# motor_p_electr_kw      0
# motor_power_cs_kw      0
# motor_eff_full_d       0
# motor_load_d           0
# motor_speed_rpm        0
# dtype: int64
#
# describe:
#                 value_date  run_id  stage_num  pump_freq_hz  p_int_atma  \
# count                 1440  1440.0     1440.0        1440.0      1440.0
# mean   2020-01-01 11:59:30     0.0      250.0          50.0       120.0
# min    2020-01-01 00:00:00     0.0      250.0          50.0       120.0
# 25%    2020-01-01 05:59:45     0.0      250.0          50.0       120.0
# 50%    2020-01-01 11:59:30     0.0      250.0          50.0       120.0
# 75%    2020-01-01 17:59:15     0.0      250.0          50.0       120.0
# max    2020-01-01 23:59:00     0.0      250.0          50.0       120.0
# std                    NaN     0.0        0.0           0.0         0.0
#
#        t_int_c       gamma_g       gamma_o  gamma_w  rsb_m3m3  ...  \
# count   1440.0  1.440000e+03  1.440000e+03   1440.0    1440.0  ...
# mean      60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# min       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# 25%       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# 50%       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# 75%       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# max       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# std        0.0  1.110609e-16  1.110609e-16      0.0       0.0  ...
#
#        motor_i_lin_a  motor_cosphi   motor_slip  motor_eff_d  \
# count    1440.000000   1440.000000  1440.000000  1440.000000
# mean       19.170543      0.806058     0.018830     0.814934
# min        18.387444      0.792662     0.017649     0.808230
# 25%        18.731939      0.798970     0.018172     0.811426
# 50%        19.132112      0.805799     0.018775     0.814841
# 75%        19.588855      0.813002     0.019459     0.818387
# max        20.105533      0.820470     0.020226     0.821999
# std         0.497637      0.008088     0.000747     0.004007
#
#        motor_p_shaft_kw  motor_p_electr_kw  motor_power_cs_kw  \
# count       1440.000000        1440.000000        1440.000000
# mean          21.820942          26.771613          28.402004
# min           20.403512          25.244687          26.782088
# 25%           21.034043          25.922306          27.500975
# 50%           21.758198          26.702400          28.328576
# 75%           22.574593          27.584266          29.264148
# max           23.486073          28.571891          30.311919
# std            0.893414           0.964145           1.022862
#
#        motor_eff_full_d  motor_load_d  motor_speed_rpm
# count       1440.000000   1440.000000      1440.000000
# mean           0.768153      0.474462      2943.510541
# min            0.761834      0.443095      2939.321988
# 25%            0.764847      0.457031      2941.624188
# 50%            0.768065      0.473057      2943.674322
# 75%            0.771408      0.491148      2945.483593
# max            0.774813      0.511379      2947.052002
# std            0.003777      0.019789         2.239610
#
# [8 rows x 47 columns]

# %%
from pathlib import Path
import matplotlib.pyplot as plt

base_dir = Path("out_demo_2h") # out_batch

for exp_dir in base_dir.glob("qwe"): # esp_* по всем
    if not exp_dir.is_dir():
        continue

    print(f"Processing {exp_dir.name}")

    for parquet_file in exp_dir.glob("*.parquet"):
        print(f"  File: {parquet_file.name}")

        df = pd.read_parquet(parquet_file)

        # берём только числовые колонки
        df = df.select_dtypes(include="number")

        for col in df.columns:
            plt.figure(figsize=(8, 4))
            df[col].plot(title=f"{exp_dir.name} | {parquet_file.name} | {col}")
            plt.grid(True)
            plt.tight_layout()
            plt.show()
# Out:
# Processing qwe
#   File: esp-system__esp_1006__run_00000.parquet
