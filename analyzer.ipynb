# %%
import pandas as pd

path = "out_system_day/esp-system__esp_1006__run_00000.parquet"

df = pd.read_parquet(path)

print("shape:", df.shape)
print("\ncolumns:")
print(df.columns.tolist())

print("\ndtypes:")
print(df.dtypes)

print("\nhead:")
display(df.head())
# Out:
# shape: (1440, 48)
#
# columns:
# ['value_date', 'esp_id', 'run_id', 'stage_num', 'pump_freq_hz', 'p_int_atma', 't_int_c', 'gamma_g', 'gamma_o', 'gamma_w', 'rsb_m3m3', 'rp_m3m3', 'pb_atma', 't_res_c', 'bob_m3m3', 'muob_cp', 'fw_fr', 'q_gas_free_sm3day', 'q_liq_sm3day', 'mu_mix_cst', 'gas_fraction_d', 'q_mix_rc_m3day', 'p_dis_atma', 't_dis_c', 'head_m', 'eff_esp_d', 'power_fluid_w', 'power_esp_w', 'system_eff_d', 'u_surf_v', 'motor_u_nom_lin_v', 'motor_p_nom_kw', 'motor_f_nom_hz', 'motor_eff_nom_fr', 'motor_cosphi_nom_fr', 'motor_slip_nom_fr', 'motor_id', 'motor_u_lin_v', 'motor_i_lin_a', 'motor_cosphi', 'motor_slip', 'motor_eff_d', 'motor_p_shaft_kw', 'motor_p_electr_kw', 'motor_power_cs_kw', 'motor_eff_full_d', 'motor_load_d', 'motor_speed_rpm']
#
# dtypes:
# value_date             datetime64[us]
# esp_id                            str
# run_id                          int64
# stage_num                       int64
# pump_freq_hz                  float64
# p_int_atma                    float64
# t_int_c                       float64
# gamma_g                       float64
# gamma_o                       float64
# gamma_w                       float64
# rsb_m3m3                      float64
# rp_m3m3                       float64
# pb_atma                       float64
# t_res_c                       float64
# bob_m3m3                      float64
# muob_cp                       float64
# fw_fr                         float64
# q_gas_free_sm3day             float64
# q_liq_sm3day                  float64
# mu_mix_cst                    float64
# gas_fraction_d                float64
# q_mix_rc_m3day                float64
# p_dis_atma                    float64
# t_dis_c                       float64
# head_m                        float64
# eff_esp_d                     float64
# power_fluid_w                 float64
# power_esp_w                   float64
# system_eff_d                  float64
# u_surf_v                      float64
# motor_u_nom_lin_v             float64
# motor_p_nom_kw                float64
# motor_f_nom_hz                float64
# motor_eff_nom_fr              float64
# motor_cosphi_nom_fr           float64
# motor_slip_nom_fr             float64
# motor_id                        int64
# motor_u_lin_v                 float64
# motor_i_lin_a                 float64
# motor_cosphi                  float64
# motor_slip                    float64
# motor_eff_d                   float64
# motor_p_shaft_kw              float64
# motor_p_electr_kw             float64
# motor_power_cs_kw             float64
# motor_eff_full_d              float64
# motor_load_d                  float64
# motor_speed_rpm               float64
# dtype: object
#
# head:
#            value_date esp_id  run_id  stage_num  pump_freq_hz  p_int_atma  \
# 0 2020-01-01 00:00:00   1006       0        250          50.0       120.0
# 1 2020-01-01 00:01:00   1006       0        250          50.0       120.0
# 2 2020-01-01 00:02:00   1006       0        250          50.0       120.0
# 3 2020-01-01 00:03:00   1006       0        250          50.0       120.0
# 4 2020-01-01 00:04:00   1006       0        250          50.0       120.0
#
#    t_int_c  gamma_g  gamma_o  gamma_w  ...  motor_i_lin_a  motor_cosphi  \
# 0     60.0      0.7     0.86      1.0  ...      18.387444      0.792662
# 1     60.0      0.7     0.86      1.0  ...      18.389897      0.792708
# 2     60.0      0.7     0.86      1.0  ...      18.392349      0.792755
# 3     60.0      0.7     0.86      1.0  ...      18.392349      0.792755
# 4     60.0      0.7     0.86      1.0  ...      18.394802      0.792801
#
#    motor_slip  motor_eff_d  motor_p_shaft_kw  motor_p_electr_kw  \
# 0    0.017649     0.808230         20.403512          25.244687
# 1    0.017653     0.808254         20.408025          25.249532
# 2    0.017657     0.808277         20.412537          25.254376
# 3    0.017657     0.808277         20.412537          25.254376
# 4    0.017661     0.808301         20.417050          25.259221
#
#    motor_power_cs_kw  motor_eff_full_d  motor_load_d  motor_speed_rpm
# 0          26.782088          0.761834      0.443095      2947.052002
# 1          26.787228          0.761857      0.443195      2947.040799
# 2          26.792368          0.761879      0.443295      2947.029596
# 3          26.792368          0.761879      0.443295      2947.029596
# 4          26.797507          0.761901      0.443394      2947.018393
#
# [5 rows x 48 columns]

# %%
# Проверка временной оси
print("min timestamp:", df["value_date"].min())
print("max timestamp:", df["value_date"].max())

print("\nunique step:")
print(df["value_date"].diff().dropna().unique())

# Есть ли пропуски
print("\nNaNs per column:")
print(df.isna().sum())

# Простая статистика
print("\ndescribe:")
display(df.describe())
# Out:
# min timestamp: 2020-01-01 00:00:00
# max timestamp: 2020-01-01 23:59:00
#
# unique step:
# <TimedeltaArray>
# ['0 days 00:01:00']
# Length: 1, dtype: timedelta64[us]
#
# NaNs per column:
# value_date             0
# esp_id                 0
# run_id                 0
# stage_num              0
# pump_freq_hz           0
# p_int_atma             0
# t_int_c                0
# gamma_g                0
# gamma_o                0
# gamma_w                0
# rsb_m3m3               0
# rp_m3m3                0
# pb_atma                0
# t_res_c                0
# bob_m3m3               0
# muob_cp                0
# fw_fr                  0
# q_gas_free_sm3day      0
# q_liq_sm3day           0
# mu_mix_cst             0
# gas_fraction_d         0
# q_mix_rc_m3day         0
# p_dis_atma             0
# t_dis_c                0
# head_m                 0
# eff_esp_d              0
# power_fluid_w          0
# power_esp_w            0
# system_eff_d           0
# u_surf_v               0
# motor_u_nom_lin_v      0
# motor_p_nom_kw         0
# motor_f_nom_hz         0
# motor_eff_nom_fr       0
# motor_cosphi_nom_fr    0
# motor_slip_nom_fr      0
# motor_id               0
# motor_u_lin_v          0
# motor_i_lin_a          0
# motor_cosphi           0
# motor_slip             0
# motor_eff_d            0
# motor_p_shaft_kw       0
# motor_p_electr_kw      0
# motor_power_cs_kw      0
# motor_eff_full_d       0
# motor_load_d           0
# motor_speed_rpm        0
# dtype: int64
#
# describe:
#                 value_date  run_id  stage_num  pump_freq_hz  p_int_atma  \
# count                 1440  1440.0     1440.0        1440.0      1440.0
# mean   2020-01-01 11:59:30     0.0      250.0          50.0       120.0
# min    2020-01-01 00:00:00     0.0      250.0          50.0       120.0
# 25%    2020-01-01 05:59:45     0.0      250.0          50.0       120.0
# 50%    2020-01-01 11:59:30     0.0      250.0          50.0       120.0
# 75%    2020-01-01 17:59:15     0.0      250.0          50.0       120.0
# max    2020-01-01 23:59:00     0.0      250.0          50.0       120.0
# std                    NaN     0.0        0.0           0.0         0.0
#
#        t_int_c       gamma_g       gamma_o  gamma_w  rsb_m3m3  ...  \
# count   1440.0  1.440000e+03  1.440000e+03   1440.0    1440.0  ...
# mean      60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# min       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# 25%       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# 50%       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# 75%       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# max       60.0  7.000000e-01  8.600000e-01      1.0     100.0  ...
# std        0.0  1.110609e-16  1.110609e-16      0.0       0.0  ...
#
#        motor_i_lin_a  motor_cosphi   motor_slip  motor_eff_d  \
# count    1440.000000   1440.000000  1440.000000  1440.000000
# mean       19.170543      0.806058     0.018830     0.814934
# min        18.387444      0.792662     0.017649     0.808230
# 25%        18.731939      0.798970     0.018172     0.811426
# 50%        19.132112      0.805799     0.018775     0.814841
# 75%        19.588855      0.813002     0.019459     0.818387
# max        20.105533      0.820470     0.020226     0.821999
# std         0.497637      0.008088     0.000747     0.004007
#
#        motor_p_shaft_kw  motor_p_electr_kw  motor_power_cs_kw  \
# count       1440.000000        1440.000000        1440.000000
# mean          21.820942          26.771613          28.402004
# min           20.403512          25.244687          26.782088
# 25%           21.034043          25.922306          27.500975
# 50%           21.758198          26.702400          28.328576
# 75%           22.574593          27.584266          29.264148
# max           23.486073          28.571891          30.311919
# std            0.893414           0.964145           1.022862
#
#        motor_eff_full_d  motor_load_d  motor_speed_rpm
# count       1440.000000   1440.000000      1440.000000
# mean           0.768153      0.474462      2943.510541
# min            0.761834      0.443095      2939.321988
# 25%            0.764847      0.457031      2941.624188
# 50%            0.768065      0.473057      2943.674322
# 75%            0.771408      0.491148      2945.483593
# max            0.774813      0.511379      2947.052002
# std            0.003777      0.019789         2.239610
#
# [8 rows x 47 columns]

# %%
from pathlib import Path
import matplotlib.pyplot as plt

base_dir = Path("out_batch")

for exp_dir in base_dir.glob("esp_736"): # esp_* по всем
    if not exp_dir.is_dir():
        continue

    print(f"Processing {exp_dir.name}")

    for parquet_file in exp_dir.glob("*.parquet"):
        print(f"  File: {parquet_file.name}")

        df = pd.read_parquet(parquet_file)

        # берём только числовые колонки
        df = df.select_dtypes(include="number")

        for col in df.columns:
            plt.figure(figsize=(8, 4))
            df[col].plot(title=f"{exp_dir.name} | {parquet_file.name} | {col}")
            plt.grid(True)
            plt.tight_layout()
            plt.show()
# Out:
# Processing esp_736
#   File: esp-system__esp_736__run_00000.parquet
